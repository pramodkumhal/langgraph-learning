# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.7)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f"generate a joke on the topic {state['topic']}"
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f"write a explanation for the joke -  {state['joke']}"
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

# Add nodes
graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

# Add edges
graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({"topic": "pizza"}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'A classic play on words. The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a pun that relies on a double meaning of the word "crusty".\n\nIn one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and golden brown. However, "crusty" can also be used to describe someone\'s personality or mood, implying that they are irritable, gruff, or unpleasant.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline "because it was feeling a little crusty" subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s mood). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'A classic play on words. The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a pun that relies on a double meaning of the word "crusty".\n\nIn one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and golden brown. However, "crusty" can also be used to describe someone\'s personality or mood, implying that they are irritable, gruff, or unpleasant.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline "because it was feeling a little crusty" subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s mood). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-9066-693b-8002-c82006b34cd8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-21T07:52:59.705555+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-8ab7-6a3d-8001-135b50840d5d'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'A classic play on words. The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a pun that relies on a double meaning of the word "crusty".\n\nIn one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and golden brown. However, "crusty" can also be used to describe someone\'s personality or mood, implying that they are irritable, gruff, or unpleasant.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline "because it was feeling a little crusty" subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s mood). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-9066-693b-8002-c82006b34cd8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-21T07:52:59.705555+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-8ab7-6a3d-8001-135b50840d5d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-8ab7-6a3d-8001-135b50840d5d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-21T07:52:59.109617+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-85d6-623c-8000-260cb4181dd7'}}, tasks=(PregelTask(id='dafb7c46-32a3-3d42-b90c-3145c87c197d', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words. The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a pun that relies on a double meaning of the word "crusty".\n\nIn one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and golden brown. However, "crusty" can also be used to describe someone\'s personality or mood, implying that they are irritable, gruff, or unpleasant.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline "because it was feeling a little crusty" subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s mood). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-85d6-623c-8000-260cb4181dd7'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-21T07:52:58.597820+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-85d0-6d90-bfff-f3a776e134f9'}}, tasks=(PregelTask(id='bf397ba2-1f09-56d5-f551-ffeaec3213d7', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16d463-85d0-6d90-bfff-f3a776e134f9'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-21T07:52:58.595656+00:00', parent_config=None, tasks=(PregelTask(id='d70967ed-968f-d795-90de-4fe7feb3c461', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2= {"configurable": {"thread_id": "2"}}
workflow.invoke({"topic": "pasta"}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.',
#  'explanation': 'A clever play on words. This joke is funny because it uses a common phrase associated with marriage, "getting tangled up in a lifelong commitment," and gives it a literal twist. \n\nIn this joke, "tangled up" has a double meaning. In the context of marriage, it means to become deeply involved or enmeshed in a relationship. However, since spaghetti is a long, thin, and flexible type of pasta, it can also become physically tangled up. \n\nThe humor comes from the unexpected shift in meaning, as the phrase "getting tangled up" is applied to an object (spaghetti) that can literally become tangled. The joke relies on this wordplay to create a humorous connection between the setup (spaghetti refusing to get married) and the punchline (being afraid of getting tangled up). \n\nThe result is a lighthearted and amusing joke that uses clever language to create a comedic effect.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.', 'explanation': 'A clever play on words. This joke is funny because it uses a common phrase associated with marriage, "getting tangled up in a lifelong commitment," and gives it a literal twist. \n\nIn this joke, "tangled up" has a double meaning. In the context of marriage, it means to become deeply involved or enmeshed in a relationship. However, since spaghetti is a long, thin, and flexible type of pasta, it can also become physically tangled up. \n\nThe humor comes from the unexpected shift in meaning, as the phrase "getting tangled up" is applied to an object (spaghetti) that can literally become tangled. The joke relies on this wordplay to create a humorous connection between the setup (spaghetti refusing to get married) and the punchline (being afraid of getting tangled up). \n\nThe result is a lighthearted and amusing joke that uses clever language to create a comedic effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-925e-6a82-8002-ccdc14e5a191'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-21T08:08:12.592582+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-8a2a-64ee-8001-75b8950ca3ff'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.', 'explanation': 'A clever play on words. This joke is funny because it uses a common phrase associated with marriage, "getting tangled up in a lifelong commitment," and gives it a literal twist. \n\nIn this joke, "tangled up" has a double meaning. In the context of marriage, it means to become deeply involved or enmeshed in a relationship. However, since spaghetti is a long, thin, and flexible type of pasta, it can also become physically tangled up. \n\nThe humor comes from the unexpected shift in meaning, as the phrase "getting tangled up" is applied to an object (spaghetti) that can literally become tangled. The joke relies on this wordplay to create a humorous connection between the setup (spaghetti refusing to get married) and the punchline (being afraid of getting tangled up). \n\nThe result is a lighthearted and amusing joke that uses clever language to create a comedic effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-925e-6a82-8002-ccdc14e5a191'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-21T08:08:12.592582+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-8a2a-64ee-8001-75b8950ca3ff'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-8a2a-64ee-8001-75b8950ca3ff'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-21T08:08:11.732275+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-87df-670c-8000-b1db00871899'}}, tasks=(PregelTask(id='8c6c97dd-7a7d-f05f-4454-6448ee981600', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A clever play on words. This joke is funny because it uses a common phrase associated with marriage, "getting tangled up in a lifelong commitment," and gives it a literal twist. \n\nIn this joke, "tangled up" has a double meaning. In the context of marriage, it means to become deeply involved or enmeshed in a relationship. However, since spaghetti is a long, thin, and flexible type of pasta, it can also become physically tangled up. \n\nThe humor comes from the unexpected shift in meaning, as the phrase "getting tangled up" is applied to an object (spaghetti) that can literally become tangled. The joke relies on this wordplay to create a humorous connection between the setup (spaghetti refusing to get married) and the punchline (being afraid of getting tangled up). \n\nThe result is a lighthearted and amusing joke that uses clever language to create a comedic effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-87df-670c-8000-b1db00871899'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-21T08:08:11.491892+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-87d9-6ca2-bfff-e08f59a0e257'}}, tasks=(PregelTask(id='c3cb8dfc-4d8c-0615-1e51-2d6607107a4e', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a lifelong commitment.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16d485-87d9-6ca2-bfff-e08f59a0e257'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-21T08:08:11.489587+00:00', parent_config=None, tasks=(PregelTask(id='6a78110f-a113-d06f-e4c8-5688c3c95ab9', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]
